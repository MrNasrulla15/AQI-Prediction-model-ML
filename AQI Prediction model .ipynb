# %%
# !git clone https://github.com/RGS-AI/Air-Quality-Index-Prediction-AICTE-Cycle-4.git
# Out:
# Cloning into 'Air-Quality-Index-Prediction-AICTE-Cycle-4'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 750.37 KiB | 6.88 MiB/s, done.
